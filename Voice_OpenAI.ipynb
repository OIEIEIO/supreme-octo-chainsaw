# %% [markdown]
# <a href="https://colab.research.google.com/github/OIEIEIO/supreme-octo-chainsaw/blob/main/Voice_OpenAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
#
# # OpenAI Neural Network - Text to Speech Synthesis
#
# ---

# %%
#@title Mount Google Drive
#@markdown - gdrive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#@title Application Creditials
#@markdown - black-stream TTS
import os

os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/content/black-stream-337600-b6d8791359e9.json'

# !echo $GOOGLE_APPLICATION_CREDENTIALS
# Out:
# /content/black-stream-337600-b6d8791359e9.json

# %%
#@title pip install
#@markdown - google-cloud-texttospeech
#@markdown - openai
# !pip install --upgrade google-cloud-texttospeech
# !pip install --upgrade openai

# %%
#@title OpenAI - Neural Network 
import os
import openai
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/content/black-stream-337600-b6d8791359e9.json'

# !echo $GOOGLE_APPLICATION_CREDENTIALS

openai.api_key = os.getenv("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")
openai.api_key = "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"

response = openai.Completion.create(
  engine="text-davinci-001",
  prompt="write a story about an explorer, Make sure the ouput is usable for text to speech", # @param
  temperature=0.8,
  max_tokens=500,
  top_p=1.0,
  frequency_penalty=0.5,
  presence_penalty=0.0,
  stop=["You:"]
)


print(response.choices[0].text)
# Out:
# /content/black-stream-337600-b6d8791359e9.json
#
#
# As an explorer, I am always looking for new and exciting adventures to embark on. Recently, I heard about a place in the middle of the ocean that was said to be full of treasure. I knew I had to find it.
#
# I set out on my ship and sailed for days, until I finally arrived at the spot. I was so excited to start searching for the treasure. But as I began to look, I realized that the ocean was much deeper than I had thought. The treasure was out of reach.
#
# I was about to give up when I had an idea. I would use my ship's anchor to try and get to the treasure. I slowly lowered it into the water, and slowly but surely, it began to drag me closer to the treasure.
#
# When I finally reached it, I couldn't believe my eyes! It was more than I could have ever hoped for. And best of all, it was all mine!

# %%
#@title Synthesizes Speech from the input string of text
#@markdown - language code = "en-US"
#@markdown - name = "en-US-Wavenet-J"
#@markdown - gender = "male"

text = response.choices[0].text

def synthesize_text(text): 

   """Synthesizes speech from the input string of text."""

from google.cloud import texttospeech

client = texttospeech.TextToSpeechClient()

input_text = texttospeech.SynthesisInput(text=text)

# Note: the voice can also be specified by name.
# Names of voices can be retrieved with client.list_voices().

voice = texttospeech.VoiceSelectionParams(
    language_code="en-US",
    name="en-US-Wavenet-J",
    ssml_gender=texttospeech.SsmlVoiceGender.MALE,
    )
audio_config = texttospeech.AudioConfig(
    audio_encoding=texttospeech.AudioEncoding.MP3
    )
response = client.synthesize_speech(
    request={"input": input_text, "voice": voice, "audio_config": audio_config}
    )
# The response's audio_content is binary.

with open("output-3.mp3", "wb") as out:
  out.write(response.audio_content)
  
print('Audio content written to file "output-3.mp3"')

# The text can be a random text.
# The audio file will be saved in the same directory as this notebook.
# 
# The audio file can be played using any media player as it is in .mp3 format.

# To remove the generated audio file, uncomment the below line.
# os.remove("output.mp3")

# The Text-To-Speech API is a **great** tool to use for the following scenarios:
# 
# * AskRemote for any audio data generation.[link text](https://)
# * If a user wants to automate the process of generating audio for multiple translations of marketing campaigns.

# I hope you enjoyed the lab!

import IPython.display as ipd
ipd.Audio(filename="output-3.mp3")
# Out:
# Audio content written to file "output-3.mp3"
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ---
#
#
# # Dual API call
#
#
# ---

# %%
#@title OpenAI - Nueral Network

#@markdown
#@markdown
#@markdown - enter text for the storyline

#@markdown
import os
import openai

openai.api_key = os.getenv("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")
openai.api_key = "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"

response = openai.Completion.create(
  engine="text-davinci-001",
  prompt="write a funny comic book description about a super chicken. Make sure the output is useable for text to speech", # @param
  temperature=0.9,
  max_tokens=150,
  top_p=1.0,
  frequency_penalty=0.5,
  presence_penalty=0.0,
  stop=["You:"]
)


print(response.choices[0].text)
#@markdown

#@markdown - suggest a list to image generation
#@markdown
response = openai.Completion.create(
  engine="text-davinci-001",
  prompt="Suggest a list 10 prompts for creating images of super chicken to be used in a text to art DALLE generator", # @param
  temperature=0.9,
  max_tokens=250,
  top_p=1.0,
  frequency_penalty=0.5,
  presence_penalty=0.0,
  stop=["You:"]
)


print(response.choices[0].text)
# Out:
# Super Chicken is the most powerful chicken in the world. He has super strength, the ability to fly, and he's immune to pain. Super Chicken is always there to help those in need, and he always does it with a smile on his face.
#
#
# 1. A super chicken stands tall, its feathers shining bright in the sun. It spreads its wings and prepares to take flight.
# 2. A super chicken surveys its kingdom, standing proud atop a mountain of food.
# 3. A super chicken flexes its powerful wings, ready to take on any enemy.
# 4. A super chicken stares down danger, unafraid of what lies ahead.
# 5. A super chicken preens its feathers, looking sharp and ready for action.
# 6. A super chicken dons a cape and mask, ready to save the world from evil villains.
# 7. A super chicken stands triumphant after vanquishing its foes.
# 8. A super chicken looks confident and ready for anything

# %%
mp3file = synthesize_text(text)

# %%
import IPython.display as ipd
ipd.Audio(filename="output-3.mp3")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
